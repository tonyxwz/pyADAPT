# %% [markdown]
# # Jacobian example

# %%
import numpy as np
from math import sin, cos
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib notebook

# %%
class F:
    
    def __init__(self):
        pass
    def __call__(self, x, y):
        F1 = x**2 * y
        F2 = 5 * x + sin(y)
        return np.asarray([F1, F2])
    
    def jac(self, x, y):
        return np.asarray([
            [2*x*y, x**2],
            [5,     cos(y)]
        ])
    def jac_det(self, x, y):
        return (2*x*y * cos(y)) - (5*x**2)

# %%
f = F()

# %%
f(2,3)
# Out:
# array([12.        , 10.14112001])

# %%
f.jac(2,3)
# Out:
# array([[12.       ,  4.       ],
#        [ 5.       , -0.9899925]])

# %%
X = np.linspace(0, 10, 100)
Y = np.linspace(0, 10, 100)

v = np.zeros([100, 100])

# %%
for i in range(len(X)):
    for j in range(len(Y)):
        v[i,j] = f.jac_det(X[i], Y[i])

# %%
plt.imshow(v)

# %%
x = np.linspace(-np.pi, np.pi, 100)
y = np.linspace(-np.pi, np.pi, 100)
X, Y = np.meshgrid(x, y)
P = np.sin(X+Y)-2*np.cos(X-Y)
Z = np.exp(P)

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, linewidth=0)
# Out:
# <img src="data:image/png;base64,..." width="512.4166666666667">

# %%
x=1;y=1

# %%
f(x,y)
# Out:
# array([1.        , 5.84147098])

# %%
jac1 = f.jac(1,1)

# %%
jac1[:,0]
# Out:
# array([2., 5.])

# %%
jac1[:,0] * jac1[:,1]
# Out:
# array([2.        , 2.70151153])

# %%
from sympy import *

# %%
x,y,z=sympy.symbols(['x', 'y', 'z'])

# %%
f = lambda x, y:sin(x+y)-2*cos(x-y)

# %%
diff(f(x,y), x)
# Out:
# 2*sin(x - y) + cos(x + y)

# %%
diff(exp(x**2), x)
# Out:
# 2*x*exp(x**2)
